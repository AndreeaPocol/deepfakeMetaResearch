# %% [markdown]
# # BigQuery:

# %%
# !pip install kaleido
import kaleido #required
kaleido.__version__ #0.2.1

# !pip install plotly==5.5.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# ## simplegan

# %%
simplegan = [{
 "num_downloads": "86",
 "month": "2022-12-01"
}, {
 "num_downloads": "315",
 "month": "2022-11-01"
}, {
 "num_downloads": "344",
 "month": "2022-10-01"
}, {
 "num_downloads": "284",
 "month": "2022-09-01"
}, {
 "num_downloads": "290",
 "month": "2022-08-01"
}, {
 "num_downloads": "247",
 "month": "2022-07-01"
}, {
 "num_downloads": "257",
 "month": "2022-06-01"
}, {
 "num_downloads": "225",
 "month": "2022-05-01"
}, {
 "num_downloads": "318",
 "month": "2022-04-01"
}, {
 "num_downloads": "614",
 "month": "2022-03-01"
}, {
 "num_downloads": "346",
 "month": "2022-02-01"
}, {
 "num_downloads": "282",
 "month": "2022-01-01"
}, {
 "num_downloads": "283",
 "month": "2021-12-01"
}, {
 "num_downloads": "248",
 "month": "2021-11-01"
}, {
 "num_downloads": "270",
 "month": "2021-10-01"
}, {
 "num_downloads": "255",
 "month": "2021-09-01"
}, {
 "num_downloads": "332",
 "month": "2021-08-01"
}, {
 "num_downloads": "373",
 "month": "2021-07-01"
}, {
 "num_downloads": "287",
 "month": "2021-06-01"
}, {
 "num_downloads": "342",
 "month": "2021-05-01"
}, {
 "num_downloads": "356",
 "month": "2021-04-01"
}, {
 "num_downloads": "463",
 "month": "2021-03-01"
}, {
 "num_downloads": "371",
 "month": "2021-02-01"
}, {
 "num_downloads": "408",
 "month": "2021-01-01"
}, {
 "num_downloads": "287",
 "month": "2020-12-01"
}, {
 "num_downloads": "415",
 "month": "2020-11-01"
}, {
 "num_downloads": "398",
 "month": "2020-10-01"
}, {
 "num_downloads": "516",
 "month": "2020-09-01"
}, {
 "num_downloads": "614",
 "month": "2020-08-01"
}, {
 "num_downloads": "365",
 "month": "2020-07-01"
}, {
 "num_downloads": "476",
 "month": "2020-06-01"
}, {
 "num_downloads": "856",
 "month": "2020-05-01"
}, {
 "num_downloads": "576",
 "month": "2020-04-01"
}, {
 "num_downloads": "2609",
 "month": "2020-03-01"
}]

# %%
import json
import pandas as pd
    
# Normalizing data
simplegan_df = pd.DataFrame(simplegan)

# %%
# Using plotly.express
import plotly.express as px

fig = px.line(simplegan_df, x='month', y='num_downloads')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## torch-mimicry

# %%
torch_mimicry = list(reversed([{
 "num_downloads": "111",
 "month": "2022-12-01"
}, {
 "num_downloads": "504",
 "month": "2022-11-01"
}, {
 "num_downloads": "466",
 "month": "2022-10-01"
}, {
 "num_downloads": "423",
 "month": "2022-09-01"
}, {
 "num_downloads": "371",
 "month": "2022-08-01"
}, {
 "num_downloads": "303",
 "month": "2022-07-01"
}, {
 "num_downloads": "351",
 "month": "2022-06-01"
}, {
 "num_downloads": "310",
 "month": "2022-05-01"
}, {
 "num_downloads": "503",
 "month": "2022-04-01"
}, {
 "num_downloads": "768",
 "month": "2022-03-01"
}, {
 "num_downloads": "513",
 "month": "2022-02-01"
}, {
 "num_downloads": "525",
 "month": "2022-01-01"
}, {
 "num_downloads": "421",
 "month": "2021-12-01"
}, {
 "num_downloads": "344",
 "month": "2021-11-01"
}, {
 "num_downloads": "511",
 "month": "2021-10-01"
}, {
 "num_downloads": "385",
 "month": "2021-09-01"
}, {
 "num_downloads": "500",
 "month": "2021-08-01"
}, {
 "num_downloads": "637",
 "month": "2021-07-01"
}, {
 "num_downloads": "631",
 "month": "2021-06-01"
}, {
 "num_downloads": "519",
 "month": "2021-05-01"
}, {
 "num_downloads": "525",
 "month": "2021-04-01"
}, {
 "num_downloads": "726",
 "month": "2021-03-01"
}, {
 "num_downloads": "521",
 "month": "2021-02-01"
}, {
 "num_downloads": "667",
 "month": "2021-01-01"
}, {
 "num_downloads": "579",
 "month": "2020-12-01"
}, {
 "num_downloads": "679",
 "month": "2020-11-01"
}, {
 "num_downloads": "707",
 "month": "2020-10-01"
}, {
 "num_downloads": "763",
 "month": "2020-09-01"
}, {
 "num_downloads": "1313",
 "month": "2020-08-01"
}, {
 "num_downloads": "343",
 "month": "2020-07-01"
}, {
 "num_downloads": "543",
 "month": "2020-06-01"
}, {
 "num_downloads": "651",
 "month": "2020-05-01"
}, {
 "num_downloads": "2741",
 "month": "2020-04-01"
}, {
 "num_downloads": "664",
 "month": "2020-03-01"
}]))

# %%
import json
import pandas as pd
    
# Normalizing data
torch_mimicry_df = pd.DataFrame(torch_mimicry)

# %%
torch_mimicry_df['num_downloads'] = pd.to_numeric(torch_mimicry_df['num_downloads'])

# %%
n = len(torch_mimicry_df)
package = ['torch_mimicry_df' for i in range(n)]
torch_mimicry_df['package'] = package

# %%
import plotly.express as px

fig = px.bar(torch_mimicry_df, y='num_downloads', x='month', text_auto='.2s',
            title="Number of Package Downloads for Each Month")
fig.update_traces(textfont_size=12, textangle=0, textposition="outside", cliponaxis=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
torch_mimicry_df_aggregated = {}
Total_Num_of_Downloads = []
for i in range(len(torch_mimicry_df)):
  y = torch_mimicry_df['month'][i].split('-')[0]
  count = int(torch_mimicry_df['num_downloads'][i])
  if y in torch_mimicry_df_aggregated.keys(): 
    torch_mimicry_df_aggregated[y] += count
  else:
    torch_mimicry_df_aggregated[y] = count

# %%
torch_mimicry_df_aggregated_df = pd.DataFrame(torch_mimicry_df_aggregated.items())
torch_mimicry_df_aggregated_df.rename(columns = {0:'Month'}, inplace = True)
torch_mimicry_df_aggregated_df.rename(columns = {1:'Number_of_Downloads'}, inplace = True)

# %%
import plotly.express as px

fig = px.bar(torch_mimicry_df_aggregated_df, y='Number_of_Downloads', x='Year', text_auto='.2s',
            title="Number of Package Downloads for Each Year")
fig.update_traces(textfont_size=12, textangle=0, textposition="outside", cliponaxis=False)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-d5f821110046> in <module>
#       1 import plotly.express as px
#       2
# ----> 3 fig = px.bar(torch_mimicry_df_aggregated_df, y='Number_of_Downloads', x='Year', text_auto='.2s',
#       4             title="Number of Package Downloads for Each Year")
#       5 fig.update_traces(textfont_size=12, textangle=0, textposition="outside", cliponaxis=False)
#
# NameError: name 'torch_mimicry_df_aggregated_df' is not defined

# %% [markdown]
# ## Torchgan

# %%
torchgan = list(reversed([{
  "num_downloads": "8520",
  "year": "2022-01-01"
}, {
  "num_downloads": "7959",
  "year": "2021-01-01"
}, {
  "num_downloads": "7016",
  "year": "2020-01-01"
}, {
  "num_downloads": "4921",
  "year": "2019-01-01"
}, {
  "num_downloads": "1325",
  "year": "2018-01-01"
}]))

# %%
torch_gan = list(reversed([{
 "num_downloads": "561",
 "month": "2022-12-01"
}, {
 "num_downloads": "654",
 "month": "2022-11-01"
}, {
 "num_downloads": "623",
 "month": "2022-10-01"
}, {
 "num_downloads": "624",
 "month": "2022-09-01"
}, {
 "num_downloads": "717",
 "month": "2022-08-01"
}, {
 "num_downloads": "506",
 "month": "2022-07-01"
}, {
 "num_downloads": "687",
 "month": "2022-06-01"
}, {
 "num_downloads": "608",
 "month": "2022-05-01"
}, {
 "num_downloads": "847",
 "month": "2022-04-01"
}, {
 "num_downloads": "1116",
 "month": "2022-03-01"
}, {
 "num_downloads": "721",
 "month": "2022-02-01"
}, {
 "num_downloads": "845",
 "month": "2022-01-01"
}, {
 "num_downloads": "795",
 "month": "2021-12-01"
}, {
 "num_downloads": "681",
 "month": "2021-11-01"
}, {
 "num_downloads": "969",
 "month": "2021-10-01"
}, {
 "num_downloads": "582",
 "month": "2021-09-01"
}, {
 "num_downloads": "601",
 "month": "2021-08-01"
}, {
 "num_downloads": "549",
 "month": "2021-07-01"
}, {
 "num_downloads": "595",
 "month": "2021-06-01"
}, {
 "num_downloads": "675",
 "month": "2021-05-01"
}, {
 "num_downloads": "570",
 "month": "2021-04-01"
}, {
 "num_downloads": "660",
 "month": "2021-03-01"
}, {
 "num_downloads": "586",
 "month": "2021-02-01"
}, {
 "num_downloads": "696",
 "month": "2021-01-01"
}, {
 "num_downloads": "596",
 "month": "2020-12-01"
}, {
 "num_downloads": "532",
 "month": "2020-11-01"
}, {
 "num_downloads": "752",
 "month": "2020-10-01"
}, {
 "num_downloads": "1153",
 "month": "2020-09-01"
}, {
 "num_downloads": "500",
 "month": "2020-08-01"
}, {
 "num_downloads": "356",
 "month": "2020-07-01"
}, {
 "num_downloads": "332",
 "month": "2020-06-01"
}, {
 "num_downloads": "478",
 "month": "2020-05-01"
}, {
 "num_downloads": "512",
 "month": "2020-04-01"
}, {
 "num_downloads": "518",
 "month": "2020-03-01"
}, {
 "num_downloads": "851",
 "month": "2020-02-01"
}, {
 "num_downloads": "436",
 "month": "2020-01-01"
}, {
 "num_downloads": "422",
 "month": "2019-12-01"
}, {
 "num_downloads": "393",
 "month": "2019-11-01"
}, {
 "num_downloads": "471",
 "month": "2019-10-01"
}, {
 "num_downloads": "1046",
 "month": "2019-09-01"
}, {
 "num_downloads": "316",
 "month": "2019-08-01"
}, {
 "num_downloads": "292",
 "month": "2019-07-01"
}, {
 "num_downloads": "324",
 "month": "2019-06-01"
}, {
 "num_downloads": "306",
 "month": "2019-05-01"
}, {
 "num_downloads": "251",
 "month": "2019-04-01"
}, {
 "num_downloads": "366",
 "month": "2019-03-01"
}, {
 "num_downloads": "302",
 "month": "2019-02-01"
}, {
 "num_downloads": "432",
 "month": "2019-01-01"
}, {
 "num_downloads": "676",
 "month": "2018-12-01"
}, {
 "num_downloads": "165",
 "month": "2018-11-01"
}, {
 "num_downloads": "484",
 "month": "2018-10-01"
}]))

# %%
import json
import pandas as pd
    
# Normalizing data
torchgan_df = pd.DataFrame(torch_gan)

# %%
torchgan_df['num_downloads'] = pd.to_numeric(torchgan_df['num_downloads'])

# %%
n = len(torchgan_df)
package = ['torchgan' for i in range(n)]
torchgan_df['package'] = package

# %%
torchgan_df.rename(columns = {'month':'Month'}, inplace = True)
torchgan_df.rename(columns = {'num_downloads':'Number_of_Downloads'}, inplace = True)

# %%
import plotly.express as px

fig = px.bar(torchgan_df, y='Number_of_Downloads', x='Month', text_auto='.2s')
fig.update_traces(textfont_size=12, textangle=0, textposition="outside", cliponaxis=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig.write_image("images/fig1.pdf")

# %%
torch_gan_df_aggregated = {}
Total_Num_of_Downloads = []
for i in range(len(torchgan_df)):
  y = torchgan_df['Month'][i].split('-')[0]
  count = int(torchgan_df['Number_of_Downloads'][i])
  if y in torch_gan_df_aggregated.keys(): 
    torch_gan_df_aggregated[y] += count
  else:
    torch_gan_df_aggregated[y] = count

# %%
torch_gan_df_aggregated_df = pd.DataFrame(torch_gan_df_aggregated.items())
torch_gan_df_aggregated_df.rename(columns = {0:'Year'}, inplace = True)
torch_gan_df_aggregated_df.rename(columns = {1:'Number_of_Downloads'}, inplace = True)

# %%
import plotly.express as px

fig = px.bar(torch_gan_df_aggregated_df, y='Number_of_Downloads', x='Year', text_auto='.2s')
fig.update_traces(textfont_size=12, textangle=0, textposition="outside", cliponaxis=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig.write_image("images/fig1_1.pdf")

# %% [markdown]
# ## Tensorflow-Gan

# %%
tf_gan = list(reversed([{
 "num_downloads": "3897",
 "month": "2022-12-01"
}, {
 "num_downloads": "11039",
 "month": "2022-11-01"
}, {
 "num_downloads": "12001",
 "month": "2022-10-01"
}, {
 "num_downloads": "16003",
 "month": "2022-09-01"
}, {
 "num_downloads": "10576",
 "month": "2022-08-01"
}, {
 "num_downloads": "13515",
 "month": "2022-07-01"
}, {
 "num_downloads": "11343",
 "month": "2022-06-01"
}, {
 "num_downloads": "12047",
 "month": "2022-05-01"
}, {
 "num_downloads": "12743",
 "month": "2022-04-01"
}, {
 "num_downloads": "15715",
 "month": "2022-03-01"
}, {
 "num_downloads": "12373",
 "month": "2022-02-01"
}, {
 "num_downloads": "83016",
 "month": "2022-01-01"
}, {
 "num_downloads": "357814",
 "month": "2021-12-01"
}, {
 "num_downloads": "309846",
 "month": "2021-11-01"
}, {
 "num_downloads": "333744",
 "month": "2021-10-01"
}, {
 "num_downloads": "446526",
 "month": "2021-09-01"
}, {
 "num_downloads": "1098437",
 "month": "2021-08-01"
}, {
 "num_downloads": "1639321",
 "month": "2021-07-01"
}, {
 "num_downloads": "266307",
 "month": "2021-06-01"
}, {
 "num_downloads": "600815",
 "month": "2021-05-01"
}, {
 "num_downloads": "81258",
 "month": "2021-04-01"
}, {
 "num_downloads": "75374",
 "month": "2021-03-01"
}, {
 "num_downloads": "110440",
 "month": "2021-02-01"
}, {
 "num_downloads": "138424",
 "month": "2021-01-01"
}, {
 "num_downloads": "96408",
 "month": "2020-12-01"
}, {
 "num_downloads": "34972",
 "month": "2020-11-01"
}, {
 "num_downloads": "58665",
 "month": "2020-10-01"
}, {
 "num_downloads": "14632",
 "month": "2020-09-01"
}, {
 "num_downloads": "14091",
 "month": "2020-08-01"
}, {
 "num_downloads": "14987",
 "month": "2020-07-01"
}, {
 "num_downloads": "13630",
 "month": "2020-06-01"
}, {
 "num_downloads": "15309",
 "month": "2020-05-01"
}, {
 "num_downloads": "21925",
 "month": "2020-04-01"
}, {
 "num_downloads": "19516",
 "month": "2020-03-01"
}, {
 "num_downloads": "25853",
 "month": "2020-02-01"
}, {
 "num_downloads": "22836",
 "month": "2020-01-01"
}, {
 "num_downloads": "21661",
 "month": "2019-12-01"
}, {
 "num_downloads": "22404",
 "month": "2019-11-01"
}, {
 "num_downloads": "19605",
 "month": "2019-10-01"
}, {
 "num_downloads": "18335",
 "month": "2019-09-01"
}, {
 "num_downloads": "3909",
 "month": "2019-08-01"
}, {
 "num_downloads": "549",
 "month": "2019-07-01"
}, {
 "num_downloads": "686",
 "month": "2019-06-01"
}, {
 "num_downloads": "342",
 "month": "2019-05-01"
}, {
 "num_downloads": "303",
 "month": "2019-04-01"
}, {
 "num_downloads": "323",
 "month": "2019-03-01"
}, {
 "num_downloads": "343",
 "month": "2019-02-01"
}]))

# %%
import json
import pandas as pd
    
# Normalizing data
tf_gan_df = pd.DataFrame(tf_gan)

# %%
tf_gan_df['num_downloads'] = pd.to_numeric(tf_gan_df['num_downloads'])

# %%
n = len(tf_gan_df)
package = ['tensorflow_gan' for i in range(n)]
tf_gan_df['package'] = package

# %%
tf_gan_df.rename(columns = {'month':'Month'}, inplace = True)
tf_gan_df.rename(columns = {'num_downloads':'Number_of_Downloads'}, inplace = True)

# %%
import plotly.express as px

fig = px.bar(tf_gan_df, y='Number_of_Downloads', x='Month', text_auto='.2s')
fig.update_traces(textfont_size=12, textangle=0, textposition="outside", cliponaxis=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig.write_image("images/fig2.pdf")

# %%
tf_gan_df_aggregated = {}
Total_Num_of_Downloads = []
for i in range(len(tf_gan_df)):
  y = tf_gan_df['Month'][i].split('-')[0]
  count = int(tf_gan_df['Number_of_Downloads'][i])
  if y in tf_gan_df_aggregated.keys(): 
    tf_gan_df_aggregated[y] += count
  else:
    tf_gan_df_aggregated[y] = count

# %%
tf_gan_df_aggregated_df = pd.DataFrame(tf_gan_df_aggregated.items())
tf_gan_df_aggregated_df.rename(columns = {0:'Year'}, inplace = True)
tf_gan_df_aggregated_df.rename(columns = {1:'Number_of_Downloads'}, inplace = True)

# %%
import plotly.express as px

fig = px.bar(tf_gan_df_aggregated_df, y='Number_of_Downloads', x='Year', text_auto='.2s')
fig.update_traces(textfont_size=12, textangle=0, textposition="outside", cliponaxis=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig.write_image("images/fig2_1.pdf")

# %% [markdown]
# ## Face Recognition

# %%
face_recognition = list(reversed([{
 "num_downloads": "27280",
 "month": "2022-12-01"
}, {
 "num_downloads": "53687",
 "month": "2022-11-01"
}, {
 "num_downloads": "49958",
 "month": "2022-10-01"
}, {
 "num_downloads": "44473",
 "month": "2022-09-01"
}, {
 "num_downloads": "41685",
 "month": "2022-08-01"
}, {
 "num_downloads": "43660",
 "month": "2022-07-01"
}, {
 "num_downloads": "50659",
 "month": "2022-06-01"
}, {
 "num_downloads": "59476",
 "month": "2022-05-01"
}, {
 "num_downloads": "51231",
 "month": "2022-04-01"
}, {
 "num_downloads": "53318",
 "month": "2022-03-01"
}, {
 "num_downloads": "42923",
 "month": "2022-02-01"
}, {
 "num_downloads": "46270",
 "month": "2022-01-01"
}, {
 "num_downloads": "51686",
 "month": "2021-12-01"
}, {
 "num_downloads": "50894",
 "month": "2021-11-01"
}, {
 "num_downloads": "53051",
 "month": "2021-10-01"
}, {
 "num_downloads": "44385",
 "month": "2021-09-01"
}, {
 "num_downloads": "46506",
 "month": "2021-08-01"
}, {
 "num_downloads": "55830",
 "month": "2021-07-01"
}, {
 "num_downloads": "71168",
 "month": "2021-06-01"
}, {
 "num_downloads": "61331",
 "month": "2021-05-01"
}, {
 "num_downloads": "51675",
 "month": "2021-04-01"
}, {
 "num_downloads": "52649",
 "month": "2021-03-01"
}, {
 "num_downloads": "39377",
 "month": "2021-02-01"
}, {
 "num_downloads": "44351",
 "month": "2021-01-01"
}, {
 "num_downloads": "48018",
 "month": "2020-12-01"
}, {
 "num_downloads": "46642",
 "month": "2020-11-01"
}, {
 "num_downloads": "46980",
 "month": "2020-10-01"
}, {
 "num_downloads": "45960",
 "month": "2020-09-01"
}, {
 "num_downloads": "46398",
 "month": "2020-08-01"
}, {
 "num_downloads": "46541",
 "month": "2020-07-01"
}, {
 "num_downloads": "48516",
 "month": "2020-06-01"
}, {
 "num_downloads": "49572",
 "month": "2020-05-01"
}, {
 "num_downloads": "47134",
 "month": "2020-04-01"
}, {
 "num_downloads": "50876",
 "month": "2020-03-01"
}, {
 "num_downloads": "48136",
 "month": "2020-02-01"
}, {
 "num_downloads": "43469",
 "month": "2020-01-01"
}, {
 "num_downloads": "41288",
 "month": "2019-12-01"
}]))

# %%
import json
import pandas as pd
    
# Normalizing data
face_recognition_df = pd.DataFrame(face_recognition)

# %%
face_recognition_df['num_downloads'] = pd.to_numeric(face_recognition_df['num_downloads'])

# %%
n = len(face_recognition_df)
package = ['face_recognition' for i in range(n)]
face_recognition_df['package'] = package

# %%
face_recognition_df.rename(columns = {'month':'Month'}, inplace = True)
face_recognition_df.rename(columns = {'num_downloads':'Number_of_Downloads'}, inplace = True)

# %%
import plotly.express as px

fig = px.bar(face_recognition_df, y='Number_of_Downloads', x='Month', text_auto='.2s')
fig.update_traces(textfont_size=12, textangle=0, textposition="outside", cliponaxis=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig.write_image("images/fig3.pdf")

# %%
face_recognition_df_aggregated = {}
Total_Num_of_Downloads = []
for i in range(len(face_recognition_df)):
  y = face_recognition_df['Month'][i].split('-')[0]
  count = int(face_recognition_df['Number_of_Downloads'][i])
  if y in face_recognition_df_aggregated.keys(): 
    face_recognition_df_aggregated[y] += count
  else:
    face_recognition_df_aggregated[y] = count

# %%
face_recognition_df_aggregated_df = pd.DataFrame(face_recognition_df_aggregated.items())
face_recognition_df_aggregated_df.rename(columns = {0:'Year'}, inplace = True)
face_recognition_df_aggregated_df.rename(columns = {1:'Number_of_Downloads'}, inplace = True)

# %%
import plotly.express as px

fig = px.bar(face_recognition_df_aggregated_df, y='Number_of_Downloads', x='Year', text_auto='.2s')
fig.update_traces(textfont_size=12, textangle=0, textposition="outside", cliponaxis=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig.write_image("images/fig3_1.pdf")

# %% [markdown]
# ## Gan-Pytorch

# %%
gan_pytorch = list(reversed([{
 "num_downloads": "214",
 "month": "2022-12-01"
}, {
 "num_downloads": "520",
 "month": "2022-11-01"
}, {
 "num_downloads": "577",
 "month": "2022-10-01"
}, {
 "num_downloads": "478",
 "month": "2022-09-01"
}, {
 "num_downloads": "574",
 "month": "2022-08-01"
}, {
 "num_downloads": "431",
 "month": "2022-07-01"
}, {
 "num_downloads": "546",
 "month": "2022-06-01"
}, {
 "num_downloads": "379",
 "month": "2022-05-01"
}, {
 "num_downloads": "528",
 "month": "2022-04-01"
}, {
 "num_downloads": "1170",
 "month": "2022-03-01"
}, {
 "num_downloads": "688",
 "month": "2022-02-01"
}, {
 "num_downloads": "648",
 "month": "2022-01-01"
}, {
 "num_downloads": "611",
 "month": "2021-12-01"
}, {
 "num_downloads": "445",
 "month": "2021-11-01"
}, {
 "num_downloads": "414",
 "month": "2021-10-01"
}, {
 "num_downloads": "589",
 "month": "2021-09-01"
}, {
 "num_downloads": "656",
 "month": "2021-08-01"
}, {
 "num_downloads": "716",
 "month": "2021-07-01"
}, {
 "num_downloads": "607",
 "month": "2021-06-01"
}, {
 "num_downloads": "633",
 "month": "2021-05-01"
}, {
 "num_downloads": "498",
 "month": "2021-04-01"
}, {
 "num_downloads": "853",
 "month": "2021-03-01"
}, {
 "num_downloads": "700",
 "month": "2021-02-01"
}, {
 "num_downloads": "663",
 "month": "2021-01-01"
}, {
 "num_downloads": "667",
 "month": "2020-12-01"
}, {
 "num_downloads": "686",
 "month": "2020-11-01"
}, {
 "num_downloads": "746",
 "month": "2020-10-01"
}, {
 "num_downloads": "813",
 "month": "2020-09-01"
}, {
 "num_downloads": "1133",
 "month": "2020-08-01"
}, {
 "num_downloads": "864",
 "month": "2020-07-01"
}, {
 "num_downloads": "915",
 "month": "2020-06-01"
}, {
 "num_downloads": "1018",
 "month": "2020-05-01"
}, {
 "num_downloads": "1125",
 "month": "2020-04-01"
}, {
 "num_downloads": "1853",
 "month": "2020-03-01"
}, {
 "num_downloads": "3424",
 "month": "2020-02-01"
}]))

# %%
import json
import pandas as pd
    
# Normalizing data
gan_pytorch_df = pd.DataFrame(gan_pytorch)

# %%
gan_pytorch_df['num_downloads'] = pd.to_numeric(gan_pytorch_df['num_downloads'])

# %%
n = len(gan_pytorch_df)
package = ['gan_pytorch' for i in range(n)]
gan_pytorch_df['package'] = package

# %%
gan_pytorch_df.rename(columns = {'month':'Month'}, inplace = True)
gan_pytorch_df.rename(columns = {'num_downloads':'Number of Downloads'}, inplace = True)

# %%
import plotly.express as px

fig = px.bar(gan_pytorch_df, y='Number of Downloads', x='Month', text_auto='.2s')
fig.update_traces(textfont_size=12, textangle=0, textposition="outside", cliponaxis=False)
fig.update_layout(title_text="", paper_bgcolor='rgba(255,255,255,1)', plot_bgcolor='rgba(255,255,255,1)', title_font_size=30)
fig.update_xaxes(showline=True, linewidth=0.01, linecolor='gray')
fig.update_yaxes(showline=True, linewidth=0.01, linecolor='gray')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig.write_image("images/face_recognition.pdf")

# %%
gan_pytorch_df_aggregated = {}
Total_Num_of_Downloads = []
for i in range(len(gan_pytorch_df)):
  y = gan_pytorch_df['Month'][i].split('-')[0]
  count = int(gan_pytorch_df['Number of Downloads'][i])
  if y in gan_pytorch_df_aggregated.keys(): 
    gan_pytorch_df_aggregated[y] += count
  else:
    gan_pytorch_df_aggregated[y] = count

# %%
gan_pytorch_df_aggregated_df = pd.DataFrame(gan_pytorch_df_aggregated.items())
gan_pytorch_df_aggregated_df.rename(columns = {0:'Year'}, inplace = True)
gan_pytorch_df_aggregated_df.rename(columns = {1:'Number of Downloads'}, inplace = True)

# %%
import plotly.express as px

fig = px.bar(gan_pytorch_df_aggregated_df, y='Number of Downloads', x='Year', text_auto='.2s')
fig.update_traces(textfont_size=12, textangle=0, textposition="outside", cliponaxis=False)
fig.update_layout(title_text="", paper_bgcolor='rgba(255,255,255,1)', plot_bgcolor='rgba(255,255,255,1)', title_font_size=30)
fig.update_xaxes(showline=True, linewidth=0.01, linecolor='black')
fig.update_yaxes(showline=True, linewidth=0.01, linecolor='black')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig.write_image("images/face_recognition_2.pdf")

# %% [markdown]
# # Plotting

# %%
import requests
import matplotlib.pyplot as plt
import csv
import pandas as pd
import plotly.express as px

def plotData(df):
    fig = px.line(df, y=df.columns, x="Year", title=title)
    fig.show()

# %% [markdown]
# # Extraction

# %%
# !pip install plotly
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import os

if not os.path.exists("images"):
    os.mkdir("images")

# %%
fig.write_image("images/fig1.pdf")

# %% [markdown]
# # All Together

# %%
frames = [tf_gan_df, face_recognition_df]
  
result = pd.concat(frames)

# %%
import pandas as pd
from sklearn import preprocessing

x = result['num_downloads'].values
df_temp = pd.DataFrame(x)
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(df_temp)
result['normalized_num_downloads'] = x_scaled

# %%
import plotly.express as px

fig = px.bar(result, x="month", y="num_downloads", color="package", title="Number of Downloaded Packages")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px

fig = px.line(result, x="month", y="num_downloads", color="package", title="Number of Downloaded Packages")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Google Play

# %%
# !pip install google-play-scraper
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from google_play_scraper import app

result = app(
    'io.faceapp',
    lang='en', # defaults to 'en'
    country='us' # defaults to 'us'
)

# %%
result
# Out:
# [{'reviewId': '5c45b196-7a39-49b4-8092-0635bf0f594d',
#   'userName': 'Arjun Gelal',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD5-WCkSqPAEZG4hhaIzc0UwOneO9oj_WAOuCEgu8PVg_Q',
#   'content': 'Nice',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '11.0.2',
#   'at': datetime.datetime(2022, 12, 17, 3, 24, 18),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': '8d3706cd-ae0e-4996-abe3-215bae4ec3f9',
#   'userName': 'sham man',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AEdFTp5oiqwaq1q-h-ccoHqoK9BruVRFQ2sMkyyjzGA0=mo',
# ...

# %%
from google_play_scraper import Sort, reviews

result, continuation_token = reviews(
    'io.faceapp',
    lang='en', # defaults to 'en'
    country='us', # defaults to 'us'
    sort=Sort.NEWEST, # defaults to Sort.NEWEST
    filter_score_with=5 # defaults to None(means all score)
)

# %%
for i in result:
  print(i)
# Out:
# {'reviewId': '5c45b196-7a39-49b4-8092-0635bf0f594d', 'userName': 'Arjun Gelal', 'userImage': 'https://play-lh.googleusercontent.com/a-/AD5-WCkSqPAEZG4hhaIzc0UwOneO9oj_WAOuCEgu8PVg_Q', 'content': 'Nice', 'score': 5, 'thumbsUpCount': 0, 'reviewCreatedVersion': '11.0.2', 'at': datetime.datetime(2022, 12, 17, 3, 24, 18), 'replyContent': None, 'repliedAt': None}
# ...
